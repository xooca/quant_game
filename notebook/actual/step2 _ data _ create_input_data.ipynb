# %%
# !pip install talib-binary
# !pip install feature_engine
# !pip install hydra-core --upgrade
# !pip install -U git+https://github.com/twopirllc/pandas-ta
# !pip install ta
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting talib-binary
#   Downloading talib_binary-0.4.19-cp37-cp37m-manylinux1_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 5.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from talib-binary) (1.21.6)
# Installing collected packages: talib-binary
# Successfully installed talib-binary-0.4.19
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting feature_engine
#   Downloading feature_engine-1.4.0-py2.py3-none-any.whl (276 kB)
#      |████████████████████████████████| 276 kB 5.1 MB/s
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from feature_engine) (1.0.2)
# Requirement already satisfied: pandas>=1.0.3 in /usr/local/lib/python3.7/dist-packages (from feature_engine) (1.3.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from feature_engine) (1.7.3)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.7/dist-packages (from feature_engine) (1.21.6)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from feature_engine) (0.12.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.3->feature_engine) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.3->feature_engine) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0.3->feature_engine) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->feature_engine) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->feature_engine) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels>=0.11.1->feature_engine) (0.5.2)
# Installing collected packages: feature-engine
# Successfully installed feature-engine-1.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hydra-core
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 5.0 MB/s
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core) (5.9.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      |████████████████████████████████| 117 kB 49.9 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from hydra-core) (21.3)
# Collecting omegaconf~=2.2
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 6.0 MB/s
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf~=2.2->hydra-core) (6.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->hydra-core) (3.8.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->hydra-core) (3.0.9)
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144575 sha256=c34e6f60c60918fa33d0ac7fef8a454194d793db7890453b2280b3bb89cc2c74
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
# Successfully built antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, omegaconf, hydra-core
# Successfully installed antlr4-python3-runtime-4.9.3 hydra-core-1.2.0 omegaconf-2.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/twopirllc/pandas-ta
#   Cloning https://github.com/twopirllc/pandas-ta to /tmp/pip-req-build-up_d36f_
#   Running command git clone -q https://github.com/twopirllc/pandas-ta /tmp/pip-req-build-up_d36f_
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas-ta==0.3.14b0) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas-ta==0.3.14b0) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas-ta==0.3.14b0) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas-ta==0.3.14b0) (2022.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas-ta==0.3.14b0) (1.15.0)
# Building wheels for collected packages: pandas-ta
#   Building wheel for pandas-ta (setup.py) ... done
#   Created wheel for pandas-ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=219766 sha256=ab32aa5b624a4731cc0e6aa054619a31b77415e4bf6bd8abec4b49f6b5d88cdf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5emzqg43/wheels/2d/b0/97/98814700c6859229dac6f4c0b1bc1546331add62e7f6c9bf15
# Successfully built pandas-ta
# Installing collected packages: pandas-ta
# Successfully installed pandas-ta-0.3.14b0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ta
#   Downloading ta-0.10.2.tar.gz (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from ta) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from ta) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->ta) (1.15.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29104 sha256=bb45217dbd9599cc81a1bc888ef3919488268fc5583a4e36e1fdd1f7053339ed
#   Stored in directory: /root/.cache/pip/wheels/31/31/f1/f2ff471bbc5b84a4b973698ceecdd453ae043971791adc3431
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.10.2

# %%
CODE_PATH = '/content/drive/MyDrive/Work/trading'
import os
from pathlib import Path
import sys
sys.path.append(CODE_PATH)

# %%
import data.data_utils as du
edp = du.execute_data_pipeline("../config/banknifty/")
# Out:
# ticker_name banknifty
# data_create_date 2022-10-06
# data_files /content/drive/MyDrive/Work/trading/data_files/
# base_data_loc /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/
# input_path /content/drive/MyDrive/Work/trading/data_files/input/banknifty/2022-10-06/banknifty.csv
# using_print print
# raw_data_input_path /content/drive/MyDrive/Work/trading/data_files/source_files/
# zip_file_pattern *.zip
# data_pattern *BANKNIFTY.txt
# source_data /content/drive/MyDrive/Work/trading/data_files/input/banknifty/2022-10-06/
# raw_data_save_path /content/drive/MyDrive/Work/trading/data_files/input/banknifty/2022-10-06/banknifty.csv
# initial_columns ['name', 'date', 'time', 'open', 'high', 'low', 'close']
# train_data_prefix training
# train_base_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/
# train_initial_file_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/banknifty_initial.csv
# train_pipeinfo /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training//pipe.pkl
# train_training_data_output_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/train.csv
# train_testing_data_output_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/test.csv
# train_validation_data_output_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/valid.csv
# train_stratify_col label_-15_1min_close_SL
# train_testing_percent 0.3
# train_validation_percent 0.3
# train_load_previous False
# train_datapipeline_spec data.feature_specs.feature_spec_v4
# predict_data_prefix prediction
# predict_base_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/prediction/
# predict_initial_file_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/prediction//banknifty_initial.csv
# predict_final_data_path /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/prediction//banknifty_final.csv
# predict_save_data 0
# verbose_type print
# data_prefix None
# initial_pipeline ['generic_pipeline']
# pipeline1 ['technical_indicator_pipe1']
# pipeline2 ['technical_indicator_pipe2']
# pipeline3 ['technical_indicator_pipe3']
# pipeline4 ['rolling_values_pipe', 'last_tick_greater_values_pipe']
# pipeline5 ['zscore_log_percentage_chg_pipe', 'rolling_rank_pipe']
# pipeline6 ['bin_transform_pipe', 'positive_negative_pipe', 'rolling_stats_pipe', 'price_range_pipe']
# pipeline7 ['label_creator_pipe']
# master_pipeline pipeline1
# master_pipeline_exclude_cols ['close', 'open', 'high', 'low']
# merge_pipeline_to_master ['pipeline2', 'pipeline3', 'pipeline4', 'pipeline5']
# pipeline2_exclude_cols ['close', 'open', 'high', 'low']
# pipeline3_exclude_cols ['close', 'open', 'high', 'low']
# pipeline4_exclude_cols ['close', 'open', 'high', 'low']
# pipeline5_exclude_cols ['close', 'open', 'high', 'low']
# pipeline6_exclude_cols ['close', 'open', 'high', 'low']
# pipeline7_exclude_cols ['close', 'open', 'high', 'low']
# read_start_date 2014-01-01
# read_end_date 2022-08-30
# save_start_date 2014-02-01
# save_end_date None
# ohlc_column ['close', 'open', 'high', 'low']
# selected_columns ['close', 'open', 'high', 'low']
# technical_indicator_col_pattern ['momentum', 'volatile', 'transform', 'pattern', 'overlap']
# label_generator_col close
# ta_pipe2_exclude ['pvo', 'vwap', 'vwma', 'ad', 'adosc', 'aobv', 'cmf', 'efi', 'eom', 'kvo', 'mfi', 'nvi', 'obv', 'pvi', 'pvol', 'pvr', 'pvt']
# hour_range [['09:00', '10:30'], ['10:30', '11:30'], ['11:30', '12:30'], ['12:30', '01:30'], ['02:30', '15:30']]
# range_type ['price_range', 'price_deviation_max_first_col', 'price_deviation_min_first_col', 'price_deviation_max_second_col', 'price_deviation_min_second_col']
# breach_type ['morethan', 'max']
# basis_column close
# tolerance 17000
# model_prefix pycaret
# model_spec_name modelling.model_pycaret_v4
# model_files /content/drive/MyDrive/Work/trading/model/
# model_base_loc /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/
# model_name pycaret_banknifty_label_-15_1min_close_SL_lightgbm
# model_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm
# model_type_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm
# model_parameter_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_hyperparameter.pkl
# model_evaluation_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_evaluation.pkl
# model_prediction_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_prediction.pkl
# model_metadata_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_metadata.pkl
# model_setup_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_setup.pkl
# model_comparison_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_comparison.pkl
# model_creation_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_creation.pkl
# model_tuned_save_path /content/drive/MyDrive/Work/trading/model/banknifty/2022-10-06/pycaret_banknifty_label_-15_1min_close_SL_lightgbm_tuned.pkl
# previous_load_setup False
# previous_load_comparison False
# previous_load_creation False
# previous_load_tuned False
# print_option print
# load_train True
# load_valid True
# load_test True
# splits_type time_based
# train_date_range_ll 2022-07-01
# train_date_range_ul 2022-07-31
# test_date_range_ll 2022-08-01
# test_date_range_ul 2022-08-15
# valid_date_range_ll 2022-08-06
# valid_date_range_ul 2022-08-31
# sampling_type others
# sampling_frac 0.4
# target_column label_-15_1min_close_SL
# label_columns ['label_-30_1min_close', 'label_-60_1min_close', 'label_-15_1min_close', 'label_-45_1min_close', 'label_-30_1min_close_SL', 'label_-60_1min_close_SL', 'label_-15_1min_close_SL', 'label_-45_1min_close_SL']
# drop_columns ['Unnamed: 0', 'HILOl_13_21', 'HILOs_13_21', 'MCGD_10', 'PSARl_0.02_0.2', 'PSARs_0.02_0.2', 'QQEl_14_5_4.236', 'QQEs_14_5_4.236', 'SUPERTl_7_3.0', 'SUPERTs_7_3.0', 'PVDR_close_w', 'PVDR_close_w_MAX_MIN', 'PVDR_open_w', 'PVDR_open_w_MAX_MIN', 'PVDR_high_w', 'PVDR_high_w_MAX_MIN', 'PVDR_low_w', 'PVDR_low_w_MAX_MIN', 'CUC_MCGD_10', 'PerChg_MCGD_10_15_None', 'PerChg_MCGD_10_30_None', 'PerChg_MCGD_10_45_None', 'PerChg_MCGD_10_60_None', 'CUC_PSARs_0.02_0.2', 'QQEs_14_5_4.236', 'CUC_SUPERTl_7_3.0', 'CUC_SUPERTs_7_3.0', 'CUC_PSARl_0.02_0.2', 'CUC_HILOl_13_21', 'CUC_HILOs_13_21']
# id_col None
# eval_metric accuracy
# load_predictor_from_path 0
# model_time_limit 12000
# use_default_parameter 0
# optimize F1
# load_parameter_from_path False
# trainer_option 2
# presets good_quality
# target label_-15_1min_close_SL
# train_size 0.7
# preprocess True
# imputation_type iterative
# iterative_imputation_iters 2
# categorical_imputation constant
# categorical_iterative_imputer lightgbm
# high_cardinality_method frequency
# numeric_imputation mean
# numeric_iterative_imputer lightgbm
# normalize False
# normalize_method zscore
# transformation False
# transformation_method yeo-johnson
# handle_unknown_categorical False
# unknown_categorical_method least_frequent
# pca False
# pca_method kernel
# ignore_low_variance False
# combine_rare_levels True
# rare_level_threshold 0.1
# remove_outliers False
# outliers_threshold 0.05
# remove_multicollinearity True
# multicollinearity_threshold 0.9
# remove_perfect_collinearity True
# create_clusters False
# cluster_iter 20
# polynomial_features False
# polynomial_degree 2
# trigonometry_features False
# polynomial_threshold 0.1
# feature_selection True
# feature_selection_threshold 0.8
# feature_selection_method classic
# feature_interaction False
# feature_ratio False
# interaction_threshold 0.01
# fix_imbalance False
# data_split_shuffle True
# data_split_stratify True
# fold_strategy timeseries
# fold 4
# fold_shuffle False
# n_jobs -1
# use_gpu False
# html True
# session_id 1234
# log_experiment False
# experiment_name Lighgbm_16min
# log_plots False
# log_profile False
# log_data False
# silent False
# verbose True
# profile False
# include ['xgboost', 'lightgbm', 'catboost', 'et', 'dummy', 'rf', 'knn', 'ada']
# n_select 6
# sort f1
# estimator lightgbm
# return_train_score True
# return_tuner False
# search_library optuna
# early_stopping Hyperband
# metric F1
# round 4
# method soft
# restack True
# choose_better True
# common common
# Feature spec file is data.feature_specs.feature_spec_v4

# %%
pipeline_obj = edp.execute_pipeline(pipeline_type='training')
# Out:
# ****************************************************************************************************
# Shape of dataframe before NormalizeDataset is (1147516, 4)
# Shape of dataframe after NormalizeDataset is (1139861, 4) :
# ****************************************************************************************************
# Value of start_date is 2014-01-01
# Value of end_date is 2022-08-30
# Value of filter_rows is None
# Data filtered with 2022-08-30
# Data filtered with filter rows None
# Initial dataframe size is (779894, 4)
# Shape of data is (779894, 4)
# Size of dataframe before transformation (779894, 4)
# *************************** Pipeline pipeline1 started.**********************************
# [Pipeline(steps=[('tech_ind_pre_ND1',
#                  NormalizeDataset(columns=['close', 'open', 'high', 'low'],
#                                   convert_to_floats=True,
#                                   impute_type='mean_median_imputer',
#                                   impute_values=True)),
#                 ('tech_indicator1',
#                  TechnicalIndicator(method_type=['momentum', 'volatile',
#                                                  'transform', 'pattern',
#                                                  'overlap'])),
#                 ('tech_indicator1_ND1',
#                  NormalizeDataset(column_pattern=['close', 'open', 'high',
#                                                   'low', 'momentum', 'volatile',
#                                                   'transform', 'pattern',
#                                                   'overlap'],
#                                   fillna=True)),
#                 ('tech_indicator1_ND2',
#                  NormalizeDataset(column_pattern=['close', 'open', 'high',
#                                                   'low', 'momentum', 'volatile',
#                                                   'transform', 'pattern',
#                                                   'overlap'],
#                                   fillna=True, fillna_method='ffill')),
#                 ('tech_indicator41',
#                  ConvertUnstableCols(transform_option='others'))])]
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline1.pkl
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline1.csv
# *************************** pipe technical_indicator_pipe1 started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('tech_ind_pre_ND1',
#                  NormalizeDataset(columns=['close', 'open', 'high', 'low'],
#                                   convert_to_floats=True,
#                                   impute_type='mean_median_imputer',
#                                   impute_values=True)),
#                 ('tech_indicator1',
#                  TechnicalIndicator(method_type=['momentum', 'volatile',
#                                                  'transform', 'pattern',
#                                                  'overlap'])),
#                 ('tech_indicator1_ND1',
#                  NormalizeDataset(column_pattern=['close', 'open', 'high',
#                                                   'low', 'momentum', 'volatile',
#                                                   'transform', 'pattern',
#                                                   'overlap'],
#                                   fillna=True)),
#                 ('tech_indicator1_ND2',
#                  NormalizeDataset(column_pattern=['close', 'open', 'high',
#                                                   'low', 'momentum', 'volatile',
#                                                   'transform', 'pattern',
#                                                   'overlap'],
#                                   fillna=True, fillna_method='ffill')),
#                 ('tech_indicator41',
#                  ConvertUnstableCols(transform_option='others'))])
# Pipe technical_indicator_pipe1 started. Shape of the data is (779894, 4)
# ****************************************************************************************************
# Shape of dataframe before NormalizeDataset is (779894, 4)
# Shape of dataframe after NormalizeDataset is (779894, 4) : convert_to_floats.convert_to_floats.convert_to_floats.convert_to_floats.mean_median_imputer
# ****************************************************************************************************
# Function momentum_AROON was unable to run, Error is Too many price arguments: expected 2 (high, low)
# Function momentum_AROONOSC was unable to run, Error is Too many price arguments: expected 2 (high, low)
# Function momentum_MACD was unable to run, Error is 'numpy.ndarray' object has no attribute 'ewm'
# Function momentum_MFI was unable to run, Error is 'Signals' object has no attribute 'volume'
# Function pattern_abondoned_baby was unable to run, Error is Invalid parameter value for penetration (expected float, got int)
# Function pattern_dark_cloud_cover was unable to run, Error is Invalid parameter value for penetration (expected float, got int)
# Function pattern_morning_doji_star was unable to run, Error is Invalid parameter value for penetration (expected float, got int)
# Function pattern_morning_star was unable to run, Error is Invalid parameter value for penetration (expected float, got int)
# Function overlap_bolliner_bands was unable to run, Error is Invalid parameter value for nbdevup (expected float, got int)
# Function overlap_mesa_adaptive_moving_average was unable to run, Error is Invalid parameter value for fastlimit (expected float, got int)
# Function overlap_moving_avg_with_variable was unable to run, Error is overlap_moving_avg_with_variable() missing 1 required positional argument: 'periods'
# Function overlap_parabolic_sar was unable to run, Error is Invalid parameter value for acceleration (expected float, got int)
# Function overlap_parabolic_sar_ext was unable to run, Error is Invalid parameter value for startvalue (expected float, got int)
# Function overlap_triple_exp_moving_average_t3 was unable to run, Error is Invalid parameter value for vfactor (expected float, got int)
# Shape of dataframe after TechnicalIndicator is (779894, 108)
# ****************************************************************************************************
# Shape of dataframe before NormalizeDataset is (779894, 108)
# Shape of dataframe after NormalizeDataset is (779894, 108) : fillna
# ****************************************************************************************************
# Shape of dataframe before NormalizeDataset is (779894, 108)
# Shape of dataframe after NormalizeDataset is (779894, 108) : fillna
# ****************************************************************************************************
# Shape of dataframe before ConvertUnstableCols is (779894, 108)
# Number of unstable columns are 14
# CUC_transform_AVGPRICE completed
# CUC_transform_MEDPRICE completed
# CUC_transform_TYPPRICE completed
# CUC_transform_WCLPRICE completed
# CUC_overlap_double_exp_moving_avg completed
# CUC_overlap_exp_moving_avg completed
# CUC_overlap_hilbert_transform completed
# CUC_overlap_kaufman_adaptive_moving_avg completed
# CUC_overlap_moving_avg completed
# CUC_overlap_midpoint completed
# CUC_overlap_midpoint_price completed
# CUC_overlap_simple_moving_avg completed
# CUC_overlap_triangular_moving_average completed
# CUC_overlap_weighted_moving_average completed
# Shape of dataframe after ConvertUnstableCols is (779894, 122)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 122)
# PerChg_transform_AVGPRICE_15_None completed
# PerChg_transform_MEDPRICE_15_None completed
# PerChg_transform_TYPPRICE_15_None completed
# PerChg_transform_WCLPRICE_15_None completed
# PerChg_overlap_double_exp_moving_avg_15_None completed
# PerChg_overlap_exp_moving_avg_15_None completed
# PerChg_overlap_hilbert_transform_15_None completed
# PerChg_overlap_kaufman_adaptive_moving_avg_15_None completed
# PerChg_overlap_moving_avg_15_None completed
# PerChg_overlap_midpoint_15_None completed
# PerChg_overlap_midpoint_price_15_None completed
# PerChg_overlap_simple_moving_avg_15_None completed
# PerChg_overlap_triangular_moving_average_15_None completed
# PerChg_overlap_weighted_moving_average_15_None completed
# Shape of dataframe after PercentageChange is (779894, 136)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 136)
# PerChg_transform_AVGPRICE_30_None completed
# PerChg_transform_MEDPRICE_30_None completed
# PerChg_transform_TYPPRICE_30_None completed
# PerChg_transform_WCLPRICE_30_None completed
# PerChg_overlap_double_exp_moving_avg_30_None completed
# PerChg_overlap_exp_moving_avg_30_None completed
# PerChg_overlap_hilbert_transform_30_None completed
# PerChg_overlap_kaufman_adaptive_moving_avg_30_None completed
# PerChg_overlap_moving_avg_30_None completed
# PerChg_overlap_midpoint_30_None completed
# PerChg_overlap_midpoint_price_30_None completed
# PerChg_overlap_simple_moving_avg_30_None completed
# PerChg_overlap_triangular_moving_average_30_None completed
# PerChg_overlap_weighted_moving_average_30_None completed
# Shape of dataframe after PercentageChange is (779894, 150)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 150)
# PerChg_transform_AVGPRICE_45_None completed
# PerChg_transform_MEDPRICE_45_None completed
# PerChg_transform_TYPPRICE_45_None completed
# PerChg_transform_WCLPRICE_45_None completed
# PerChg_overlap_double_exp_moving_avg_45_None completed
# PerChg_overlap_exp_moving_avg_45_None completed
# PerChg_overlap_hilbert_transform_45_None completed
# PerChg_overlap_kaufman_adaptive_moving_avg_45_None completed
# PerChg_overlap_moving_avg_45_None completed
# PerChg_overlap_midpoint_45_None completed
# PerChg_overlap_midpoint_price_45_None completed
# PerChg_overlap_simple_moving_avg_45_None completed
# PerChg_overlap_triangular_moving_average_45_None completed
# PerChg_overlap_weighted_moving_average_45_None completed
# Shape of dataframe after PercentageChange is (779894, 164)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 164)
# PerChg_transform_AVGPRICE_60_None completed
# PerChg_transform_MEDPRICE_60_None completed
# PerChg_transform_TYPPRICE_60_None completed
# PerChg_transform_WCLPRICE_60_None completed
# PerChg_overlap_double_exp_moving_avg_60_None completed
# PerChg_overlap_exp_moving_avg_60_None completed
# PerChg_overlap_hilbert_transform_60_None completed
# PerChg_overlap_kaufman_adaptive_moving_avg_60_None completed
# PerChg_overlap_moving_avg_60_None completed
# PerChg_overlap_midpoint_60_None completed
# PerChg_overlap_midpoint_price_60_None completed
# PerChg_overlap_simple_moving_avg_60_None completed
# PerChg_overlap_triangular_moving_average_60_None completed
# PerChg_overlap_weighted_moving_average_60_None completed
# Shape of dataframe after PercentageChange is (779894, 178)
# Shape of dataframe after applying transform in ConvertUnstableCols is (779894, 178)
# Shape of dataframe after dropping unstable columns is (779894, 164)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline1/pipe_technical_indicator_pipe1.pkl saved
# pipe technical_indicator_pipe1 completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline1/pipe_technical_indicator_pipe1.pkl
# After completion of pipe technical_indicator_pipe1, shape of the data is (779894, 164)
# *************************** Pipeline pipeline1 completed.**********************************
# *************************** Pipeline pipeline2 started.**********************************
# [Pipeline(steps=[('tech_ind_pre_ND2',
#                  NormalizeDataset(columns=['close', 'open', 'high', 'low'],
#                                   convert_to_floats=True,
#                                   impute_type='mean_median_imputer',
#                                   impute_values=True)),
#                 ('tech_indicator2', CreateTechnicalIndicatorUsingPandasTA()),
#                 ('tech_indicator42',
#                  ConvertUnstableCols(transform_option='others'))])]
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline2.pkl
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline2.csv
# *************************** pipe technical_indicator_pipe2 started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('tech_ind_pre_ND2',
#                  NormalizeDataset(columns=['close', 'open', 'high', 'low'],
#                                   convert_to_floats=True,
#                                   impute_type='mean_median_imputer',
#                                   impute_values=True)),
#                 ('tech_indicator2', CreateTechnicalIndicatorUsingPandasTA()),
#                 ('tech_indicator42',
#                  ConvertUnstableCols(transform_option='others'))])
# Pipe technical_indicator_pipe2 started. Shape of the data is (779894, 4)
# ****************************************************************************************************
# Shape of dataframe before NormalizeDataset is (779894, 4)
# Shape of dataframe after NormalizeDataset is (779894, 4) : convert_to_floats.convert_to_floats.convert_to_floats.convert_to_floats.mean_median_imputer
# ****************************************************************************************************
# Shape of dataframe before CreateTechnicalIndicatorUsingPandasTA is (779894, 4)
# [+] Strategy: All
# [i] Indicator arguments: {'timed': True, 'append': True}
# [i] Excluded[29]: above, above_value, below, below_value, cross, cross_value, long_run, short_run, td_seq, tsignals, vp, xsignals, pvo, vwap, vwma, ad, adosc, aobv, cmf, efi, eom, kvo, mfi, nvi, obv, pvi, pvol, pvr, pvt
# [i] Multiprocessing 114 indicators with 3 chunks and 4/4 cpus.
# 114it [10:30,  5.53s/it]
# [i] Total indicators: 114
# [i] Columns added: 253
# [i] Last Run: Sunday October 9, 2022, NYSE: 8:05:03, Local: 12:05:03 UTC, Day 282/365 (77.00%)
# [i] Runtime: 630848.1524 ms (630.8482 s)
# Shape of dataframe after CreateTechnicalIndicatorUsingPandasTA is (779894, 257)
# ****************************************************************************************************
# Shape of dataframe before ConvertUnstableCols is (779894, 257)
# Number of unstable columns are 73
# CUC_ABER_ZG_5_15 completed
# CUC_ABER_SG_5_15 completed
# CUC_ABER_XG_5_15 completed
# CUC_ACCBL_20 completed
# CUC_ACCBM_20 completed
# CUC_ACCBU_20 completed
# CUC_ALMA_10_6.0_0.85 completed
# CUC_BBL_5_2.0 completed
# CUC_BBM_5_2.0 completed
# CUC_BBU_5_2.0 completed
# CUC_CKSPl_10_3_20 completed
# CUC_CKSPs_10_3_20 completed
# CUC_LDECAY_5 completed
# CUC_DEMA_10 completed
# CUC_DCL_20_20 completed
# CUC_DCM_20_20 completed
# CUC_DCU_20_20 completed
# CUC_EMA_10 completed
# CUC_FWMA_10 completed
# CUC_HA_open completed
# CUC_HA_high completed
# CUC_HA_low completed
# CUC_HA_close completed
# CUC_HILO_13_21 completed
# CUC_HILOl_13_21 completed
# CUC_HILOs_13_21 completed
# CUC_HL2 completed
# CUC_HLC3 completed
# CUC_HMA_10 completed
# CUC_HWM completed
# CUC_HWU completed
# CUC_HWL completed
# CUC_HWMA_0.2_0.1_0.1 completed
# CUC_ISA_9 completed
# CUC_ISB_26 completed
# CUC_ITS_9 completed
# CUC_IKS_26 completed
# CUC_ICS_26 completed
# CUC_JMA_7_0 completed
# CUC_KAMA_10_2_30 completed
# CUC_KCLe_20_2 completed
# CUC_KCBe_20_2 completed
# CUC_KCUe_20_2 completed
# CUC_LR_14 completed
# CUC_MCGD_10 completed
# CUC_MEDIAN_30 completed
# CUC_MIDPOINT_2 completed
# CUC_MIDPRICE_2 completed
# CUC_OHLC4 completed
# CUC_PSARl_0.02_0.2 completed
# CUC_PSARs_0.02_0.2 completed
# CUC_PWMA_10 completed
# CUC_QTL_30_0.5 completed
# CUC_RMA_10 completed
# CUC_SINWMA_14 completed
# CUC_SMA_10 completed
# CUC_SSF_10_2 completed
# CUC_SUPERT_7_3.0 completed
# CUC_SUPERTl_7_3.0 completed
# CUC_SUPERTs_7_3.0 completed
# CUC_SWMA_10 completed
# CUC_T3_10_0.7 completed
# CUC_TEMA_10 completed
# CUC_TOS_STDEVALL_LR completed
# CUC_TOS_STDEVALL_L_1 completed
# CUC_TOS_STDEVALL_U_1 completed
# CUC_TOS_STDEVALL_U_2 completed
# CUC_TOS_STDEVALL_U_3 completed
# CUC_TRIMA_10 completed
# CUC_VIDYA_14 completed
# CUC_WCP completed
# CUC_WMA_10 completed
# CUC_ZL_EMA_10 completed
# Shape of dataframe after ConvertUnstableCols is (779894, 330)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 330)
# PerChg_ABER_ZG_5_15_15_None completed
# PerChg_ABER_SG_5_15_15_None completed
# PerChg_ABER_XG_5_15_15_None completed
# PerChg_ACCBL_20_15_None completed
# PerChg_ACCBM_20_15_None completed
# PerChg_ACCBU_20_15_None completed
# PerChg_ALMA_10_6.0_0.85_15_None completed
# PerChg_BBL_5_2.0_15_None completed
# PerChg_BBM_5_2.0_15_None completed
# PerChg_BBU_5_2.0_15_None completed
# PerChg_CKSPl_10_3_20_15_None completed
# PerChg_CKSPs_10_3_20_15_None completed
# PerChg_LDECAY_5_15_None completed
# PerChg_DEMA_10_15_None completed
# PerChg_DCL_20_20_15_None completed
# PerChg_DCM_20_20_15_None completed
# PerChg_DCU_20_20_15_None completed
# PerChg_EMA_10_15_None completed
# PerChg_FWMA_10_15_None completed
# PerChg_HA_open_15_None completed
# PerChg_HA_high_15_None completed
# PerChg_HA_low_15_None completed
# PerChg_HA_close_15_None completed
# PerChg_HILO_13_21_15_None completed
# PerChg_HILOl_13_21_15_None completed
# PerChg_HILOs_13_21_15_None completed
# PerChg_HL2_15_None completed
# PerChg_HLC3_15_None completed
# PerChg_HMA_10_15_None completed
# PerChg_HWM_15_None completed
# PerChg_HWU_15_None completed
# PerChg_HWL_15_None completed
# PerChg_HWMA_0.2_0.1_0.1_15_None completed
# PerChg_ISA_9_15_None completed
# PerChg_ISB_26_15_None completed
# PerChg_ITS_9_15_None completed
# PerChg_IKS_26_15_None completed
# PerChg_ICS_26_15_None completed
# PerChg_JMA_7_0_15_None completed
# PerChg_KAMA_10_2_30_15_None completed
# PerChg_KCLe_20_2_15_None completed
# PerChg_KCBe_20_2_15_None completed
# PerChg_KCUe_20_2_15_None completed
# PerChg_LR_14_15_None completed
# PerChg_MCGD_10_15_None completed
# PerChg_MEDIAN_30_15_None completed
# PerChg_MIDPOINT_2_15_None completed
# PerChg_MIDPRICE_2_15_None completed
# PerChg_OHLC4_15_None completed
# PerChg_PSARl_0.02_0.2_15_None completed
# PerChg_PSARs_0.02_0.2_15_None completed
# PerChg_PWMA_10_15_None completed
# PerChg_QTL_30_0.5_15_None completed
# PerChg_RMA_10_15_None completed
# PerChg_SINWMA_14_15_None completed
# PerChg_SMA_10_15_None completed
# PerChg_SSF_10_2_15_None completed
# PerChg_SUPERT_7_3.0_15_None completed
# PerChg_SUPERTl_7_3.0_15_None completed
# PerChg_SUPERTs_7_3.0_15_None completed
# PerChg_SWMA_10_15_None completed
# PerChg_T3_10_0.7_15_None completed
# PerChg_TEMA_10_15_None completed
# PerChg_TOS_STDEVALL_LR_15_None completed
# PerChg_TOS_STDEVALL_L_1_15_None completed
# PerChg_TOS_STDEVALL_U_1_15_None completed
# PerChg_TOS_STDEVALL_U_2_15_None completed
# PerChg_TOS_STDEVALL_U_3_15_None completed
# PerChg_TRIMA_10_15_None completed
# PerChg_VIDYA_14_15_None completed
# PerChg_WCP_15_None completed
# PerChg_WMA_10_15_None completed
# PerChg_ZL_EMA_10_15_None completed
# Shape of dataframe after PercentageChange is (779894, 403)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 403)
# PerChg_ABER_ZG_5_15_30_None completed
# PerChg_ABER_SG_5_15_30_None completed
# PerChg_ABER_XG_5_15_30_None completed
# PerChg_ACCBL_20_30_None completed
# PerChg_ACCBM_20_30_None completed
# PerChg_ACCBU_20_30_None completed
# PerChg_ALMA_10_6.0_0.85_30_None completed
# PerChg_BBL_5_2.0_30_None completed
# PerChg_BBM_5_2.0_30_None completed
# PerChg_BBU_5_2.0_30_None completed
# PerChg_CKSPl_10_3_20_30_None completed
# PerChg_CKSPs_10_3_20_30_None completed
# PerChg_LDECAY_5_30_None completed
# PerChg_DEMA_10_30_None completed
# PerChg_DCL_20_20_30_None completed
# PerChg_DCM_20_20_30_None completed
# PerChg_DCU_20_20_30_None completed
# PerChg_EMA_10_30_None completed
# PerChg_FWMA_10_30_None completed
# PerChg_HA_open_30_None completed
# PerChg_HA_high_30_None completed
# PerChg_HA_low_30_None completed
# PerChg_HA_close_30_None completed
# PerChg_HILO_13_21_30_None completed
# PerChg_HILOl_13_21_30_None completed
# PerChg_HILOs_13_21_30_None completed
# PerChg_HL2_30_None completed
# PerChg_HLC3_30_None completed
# PerChg_HMA_10_30_None completed
# PerChg_HWM_30_None completed
# PerChg_HWU_30_None completed
# PerChg_HWL_30_None completed
# PerChg_HWMA_0.2_0.1_0.1_30_None completed
# PerChg_ISA_9_30_None completed
# PerChg_ISB_26_30_None completed
# PerChg_ITS_9_30_None completed
# PerChg_IKS_26_30_None completed
# PerChg_ICS_26_30_None completed
# PerChg_JMA_7_0_30_None completed
# PerChg_KAMA_10_2_30_30_None completed
# PerChg_KCLe_20_2_30_None completed
# PerChg_KCBe_20_2_30_None completed
# PerChg_KCUe_20_2_30_None completed
# PerChg_LR_14_30_None completed
# PerChg_MCGD_10_30_None completed
# PerChg_MEDIAN_30_30_None completed
# PerChg_MIDPOINT_2_30_None completed
# PerChg_MIDPRICE_2_30_None completed
# PerChg_OHLC4_30_None completed
# PerChg_PSARl_0.02_0.2_30_None completed
# PerChg_PSARs_0.02_0.2_30_None completed
# PerChg_PWMA_10_30_None completed
# PerChg_QTL_30_0.5_30_None completed
# PerChg_RMA_10_30_None completed
# PerChg_SINWMA_14_30_None completed
# PerChg_SMA_10_30_None completed
# PerChg_SSF_10_2_30_None completed
# PerChg_SUPERT_7_3.0_30_None completed
# PerChg_SUPERTl_7_3.0_30_None completed
# PerChg_SUPERTs_7_3.0_30_None completed
# PerChg_SWMA_10_30_None completed
# PerChg_T3_10_0.7_30_None completed
# PerChg_TEMA_10_30_None completed
# PerChg_TOS_STDEVALL_LR_30_None completed
# PerChg_TOS_STDEVALL_L_1_30_None completed
# PerChg_TOS_STDEVALL_U_1_30_None completed
# PerChg_TOS_STDEVALL_U_2_30_None completed
# PerChg_TOS_STDEVALL_U_3_30_None completed
# PerChg_TRIMA_10_30_None completed
# PerChg_VIDYA_14_30_None completed
# PerChg_WCP_30_None completed
# PerChg_WMA_10_30_None completed
# PerChg_ZL_EMA_10_30_None completed
# Shape of dataframe after PercentageChange is (779894, 476)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 476)
# PerChg_ABER_ZG_5_15_45_None completed
# PerChg_ABER_SG_5_15_45_None completed
# PerChg_ABER_XG_5_15_45_None completed
# PerChg_ACCBL_20_45_None completed
# PerChg_ACCBM_20_45_None completed
# PerChg_ACCBU_20_45_None completed
# PerChg_ALMA_10_6.0_0.85_45_None completed
# PerChg_BBL_5_2.0_45_None completed
# PerChg_BBM_5_2.0_45_None completed
# PerChg_BBU_5_2.0_45_None completed
# PerChg_CKSPl_10_3_20_45_None completed
# PerChg_CKSPs_10_3_20_45_None completed
# PerChg_LDECAY_5_45_None completed
# PerChg_DEMA_10_45_None completed
# PerChg_DCL_20_20_45_None completed
# PerChg_DCM_20_20_45_None completed
# PerChg_DCU_20_20_45_None completed
# PerChg_EMA_10_45_None completed
# PerChg_FWMA_10_45_None completed
# PerChg_HA_open_45_None completed
# PerChg_HA_high_45_None completed
# PerChg_HA_low_45_None completed
# PerChg_HA_close_45_None completed
# PerChg_HILO_13_21_45_None completed
# PerChg_HILOl_13_21_45_None completed
# PerChg_HILOs_13_21_45_None completed
# PerChg_HL2_45_None completed
# PerChg_HLC3_45_None completed
# PerChg_HMA_10_45_None completed
# PerChg_HWM_45_None completed
# PerChg_HWU_45_None completed
# PerChg_HWL_45_None completed
# PerChg_HWMA_0.2_0.1_0.1_45_None completed
# PerChg_ISA_9_45_None completed
# PerChg_ISB_26_45_None completed
# PerChg_ITS_9_45_None completed
# PerChg_IKS_26_45_None completed
# PerChg_ICS_26_45_None completed
# PerChg_JMA_7_0_45_None completed
# PerChg_KAMA_10_2_30_45_None completed
# PerChg_KCLe_20_2_45_None completed
# PerChg_KCBe_20_2_45_None completed
# PerChg_KCUe_20_2_45_None completed
# PerChg_LR_14_45_None completed
# PerChg_MCGD_10_45_None completed
# PerChg_MEDIAN_30_45_None completed
# PerChg_MIDPOINT_2_45_None completed
# PerChg_MIDPRICE_2_45_None completed
# PerChg_OHLC4_45_None completed
# PerChg_PSARl_0.02_0.2_45_None completed
# PerChg_PSARs_0.02_0.2_45_None completed
# PerChg_PWMA_10_45_None completed
# PerChg_QTL_30_0.5_45_None completed
# PerChg_RMA_10_45_None completed
# PerChg_SINWMA_14_45_None completed
# PerChg_SMA_10_45_None completed
# PerChg_SSF_10_2_45_None completed
# PerChg_SUPERT_7_3.0_45_None completed
# PerChg_SUPERTl_7_3.0_45_None completed
# PerChg_SUPERTs_7_3.0_45_None completed
# PerChg_SWMA_10_45_None completed
# PerChg_T3_10_0.7_45_None completed
# PerChg_TEMA_10_45_None completed
# PerChg_TOS_STDEVALL_LR_45_None completed
# PerChg_TOS_STDEVALL_L_1_45_None completed
# PerChg_TOS_STDEVALL_U_1_45_None completed
# PerChg_TOS_STDEVALL_U_2_45_None completed
# PerChg_TOS_STDEVALL_U_3_45_None completed
# PerChg_TRIMA_10_45_None completed
# PerChg_VIDYA_14_45_None completed
# PerChg_WCP_45_None completed
# PerChg_WMA_10_45_None completed
# PerChg_ZL_EMA_10_45_None completed
# Shape of dataframe after PercentageChange is (779894, 549)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 549)
# PerChg_ABER_ZG_5_15_60_None completed
# PerChg_ABER_SG_5_15_60_None completed
# PerChg_ABER_XG_5_15_60_None completed
# PerChg_ACCBL_20_60_None completed
# PerChg_ACCBM_20_60_None completed
# PerChg_ACCBU_20_60_None completed
# PerChg_ALMA_10_6.0_0.85_60_None completed
# PerChg_BBL_5_2.0_60_None completed
# PerChg_BBM_5_2.0_60_None completed
# PerChg_BBU_5_2.0_60_None completed
# PerChg_CKSPl_10_3_20_60_None completed
# PerChg_CKSPs_10_3_20_60_None completed
# PerChg_LDECAY_5_60_None completed
# PerChg_DEMA_10_60_None completed
# PerChg_DCL_20_20_60_None completed
# PerChg_DCM_20_20_60_None completed
# PerChg_DCU_20_20_60_None completed
# PerChg_EMA_10_60_None completed
# PerChg_FWMA_10_60_None completed
# PerChg_HA_open_60_None completed
# PerChg_HA_high_60_None completed
# PerChg_HA_low_60_None completed
# PerChg_HA_close_60_None completed
# PerChg_HILO_13_21_60_None completed
# PerChg_HILOl_13_21_60_None completed
# PerChg_HILOs_13_21_60_None completed
# PerChg_HL2_60_None completed
# PerChg_HLC3_60_None completed
# PerChg_HMA_10_60_None completed
# PerChg_HWM_60_None completed
# PerChg_HWU_60_None completed
# PerChg_HWL_60_None completed
# PerChg_HWMA_0.2_0.1_0.1_60_None completed
# PerChg_ISA_9_60_None completed
# PerChg_ISB_26_60_None completed
# PerChg_ITS_9_60_None completed
# PerChg_IKS_26_60_None completed
# PerChg_ICS_26_60_None completed
# PerChg_JMA_7_0_60_None completed
# PerChg_KAMA_10_2_30_60_None completed
# PerChg_KCLe_20_2_60_None completed
# PerChg_KCBe_20_2_60_None completed
# PerChg_KCUe_20_2_60_None completed
# PerChg_LR_14_60_None completed
# PerChg_MCGD_10_60_None completed
# PerChg_MEDIAN_30_60_None completed
# PerChg_MIDPOINT_2_60_None completed
# PerChg_MIDPRICE_2_60_None completed
# PerChg_OHLC4_60_None completed
# PerChg_PSARl_0.02_0.2_60_None completed
# PerChg_PSARs_0.02_0.2_60_None completed
# PerChg_PWMA_10_60_None completed
# PerChg_QTL_30_0.5_60_None completed
# PerChg_RMA_10_60_None completed
# PerChg_SINWMA_14_60_None completed
# PerChg_SMA_10_60_None completed
# PerChg_SSF_10_2_60_None completed
# PerChg_SUPERT_7_3.0_60_None completed
# PerChg_SUPERTl_7_3.0_60_None completed
# PerChg_SUPERTs_7_3.0_60_None completed
# PerChg_SWMA_10_60_None completed
# PerChg_T3_10_0.7_60_None completed
# PerChg_TEMA_10_60_None completed
# PerChg_TOS_STDEVALL_LR_60_None completed
# PerChg_TOS_STDEVALL_L_1_60_None completed
# PerChg_TOS_STDEVALL_U_1_60_None completed
# PerChg_TOS_STDEVALL_U_2_60_None completed
# PerChg_TOS_STDEVALL_U_3_60_None completed
# PerChg_TRIMA_10_60_None completed
# PerChg_VIDYA_14_60_None completed
# PerChg_WCP_60_None completed
# PerChg_WMA_10_60_None completed
# PerChg_ZL_EMA_10_60_None completed
# Shape of dataframe after PercentageChange is (779894, 622)
# Shape of dataframe after applying transform in ConvertUnstableCols is (779894, 622)
# Shape of dataframe after dropping unstable columns is (779894, 549)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline2/pipe_technical_indicator_pipe2.pkl saved
# pipe technical_indicator_pipe2 completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline2/pipe_technical_indicator_pipe2.pkl
# After completion of pipe technical_indicator_pipe2, shape of the data is (779894, 549)
# *************************** Pipeline pipeline2 completed.**********************************
# *************************** Pipeline pipeline3 started.**********************************
# [Pipeline(steps=[('tech_ind_pre_ND3',
#                  NormalizeDataset(columns=['close', 'open', 'high', 'low'],
#                                   convert_to_floats=True,
#                                   impute_type='mean_median_imputer',
#                                   impute_values=True)),
#                 ('tech_indicator3',
#                  CreateTechnicalIndicatorUsingTA(volume_ta=False)),
#                 ('tech_indicator43',
#                  ConvertUnstableCols(transform_option='others'))])]
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline3.pkl
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline3.csv
# *************************** pipe technical_indicator_pipe3 started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('tech_ind_pre_ND3',
#                  NormalizeDataset(columns=['close', 'open', 'high', 'low'],
#                                   convert_to_floats=True,
#                                   impute_type='mean_median_imputer',
#                                   impute_values=True)),
#                 ('tech_indicator3',
#                  CreateTechnicalIndicatorUsingTA(volume_ta=False)),
#                 ('tech_indicator43',
#                  ConvertUnstableCols(transform_option='others'))])
# Pipe technical_indicator_pipe3 started. Shape of the data is (779894, 4)
# ****************************************************************************************************
# Shape of dataframe before NormalizeDataset is (779894, 4)
# Shape of dataframe after NormalizeDataset is (779894, 4) : convert_to_floats.convert_to_floats.convert_to_floats.convert_to_floats.mean_median_imputer
# ****************************************************************************************************
# Shape of dataframe before CreateTechnicalIndicatorUsingTA is (779894, 4)
# Shape of dataframe after CreateTechnicalIndicatorUsingTA is (779894, 61)
# ****************************************************************************************************
# Shape of dataframe before ConvertUnstableCols is (779894, 61)
# Number of unstable columns are 17
# CUC_tavolatility_bbm completed
# CUC_tavolatility_bbh completed
# CUC_tavolatility_bbl completed
# CUC_tavolatility_kcc completed
# CUC_tavolatility_kch completed
# CUC_tavolatility_kcl completed
# CUC_tavolatility_dcl completed
# CUC_tavolatility_dch completed
# CUC_tavolatility_dcm completed
# CUC_tatrend_sma_fast completed
# CUC_tatrend_sma_slow completed
# CUC_tatrend_ema_fast completed
# CUC_tatrend_ema_slow completed
# CUC_tatrend_ichimoku_conv completed
# CUC_tatrend_ichimoku_base completed
# CUC_tatrend_ichimoku_a completed
# CUC_tatrend_ichimoku_b completed
# Shape of dataframe after ConvertUnstableCols is (779894, 78)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 78)
# PerChg_tavolatility_bbm_15_None completed
# PerChg_tavolatility_bbh_15_None completed
# PerChg_tavolatility_bbl_15_None completed
# PerChg_tavolatility_kcc_15_None completed
# PerChg_tavolatility_kch_15_None completed
# PerChg_tavolatility_kcl_15_None completed
# PerChg_tavolatility_dcl_15_None completed
# PerChg_tavolatility_dch_15_None completed
# PerChg_tavolatility_dcm_15_None completed
# PerChg_tatrend_sma_fast_15_None completed
# PerChg_tatrend_sma_slow_15_None completed
# PerChg_tatrend_ema_fast_15_None completed
# PerChg_tatrend_ema_slow_15_None completed
# PerChg_tatrend_ichimoku_conv_15_None completed
# PerChg_tatrend_ichimoku_base_15_None completed
# PerChg_tatrend_ichimoku_a_15_None completed
# PerChg_tatrend_ichimoku_b_15_None completed
# Shape of dataframe after PercentageChange is (779894, 95)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 95)
# PerChg_tavolatility_bbm_30_None completed
# PerChg_tavolatility_bbh_30_None completed
# PerChg_tavolatility_bbl_30_None completed
# PerChg_tavolatility_kcc_30_None completed
# PerChg_tavolatility_kch_30_None completed
# PerChg_tavolatility_kcl_30_None completed
# PerChg_tavolatility_dcl_30_None completed
# PerChg_tavolatility_dch_30_None completed
# PerChg_tavolatility_dcm_30_None completed
# PerChg_tatrend_sma_fast_30_None completed
# PerChg_tatrend_sma_slow_30_None completed
# PerChg_tatrend_ema_fast_30_None completed
# PerChg_tatrend_ema_slow_30_None completed
# PerChg_tatrend_ichimoku_conv_30_None completed
# PerChg_tatrend_ichimoku_base_30_None completed
# PerChg_tatrend_ichimoku_a_30_None completed
# PerChg_tatrend_ichimoku_b_30_None completed
# Shape of dataframe after PercentageChange is (779894, 112)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 112)
# PerChg_tavolatility_bbm_45_None completed
# PerChg_tavolatility_bbh_45_None completed
# PerChg_tavolatility_bbl_45_None completed
# PerChg_tavolatility_kcc_45_None completed
# PerChg_tavolatility_kch_45_None completed
# PerChg_tavolatility_kcl_45_None completed
# PerChg_tavolatility_dcl_45_None completed
# PerChg_tavolatility_dch_45_None completed
# PerChg_tavolatility_dcm_45_None completed
# PerChg_tatrend_sma_fast_45_None completed
# PerChg_tatrend_sma_slow_45_None completed
# PerChg_tatrend_ema_fast_45_None completed
# PerChg_tatrend_ema_slow_45_None completed
# PerChg_tatrend_ichimoku_conv_45_None completed
# PerChg_tatrend_ichimoku_base_45_None completed
# PerChg_tatrend_ichimoku_a_45_None completed
# PerChg_tatrend_ichimoku_b_45_None completed
# Shape of dataframe after PercentageChange is (779894, 129)
# ****************************************************************************************************
# Shape of dataframe before PercentageChange is (779894, 129)
# PerChg_tavolatility_bbm_60_None completed
# PerChg_tavolatility_bbh_60_None completed
# PerChg_tavolatility_bbl_60_None completed
# PerChg_tavolatility_kcc_60_None completed
# PerChg_tavolatility_kch_60_None completed
# PerChg_tavolatility_kcl_60_None completed
# PerChg_tavolatility_dcl_60_None completed
# PerChg_tavolatility_dch_60_None completed
# PerChg_tavolatility_dcm_60_None completed
# PerChg_tatrend_sma_fast_60_None completed
# PerChg_tatrend_sma_slow_60_None completed
# PerChg_tatrend_ema_fast_60_None completed
# PerChg_tatrend_ema_slow_60_None completed
# PerChg_tatrend_ichimoku_conv_60_None completed
# PerChg_tatrend_ichimoku_base_60_None completed
# PerChg_tatrend_ichimoku_a_60_None completed
# PerChg_tatrend_ichimoku_b_60_None completed
# Shape of dataframe after PercentageChange is (779894, 146)
# Shape of dataframe after applying transform in ConvertUnstableCols is (779894, 146)
# Shape of dataframe after dropping unstable columns is (779894, 129)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline3/pipe_technical_indicator_pipe3.pkl saved
# pipe technical_indicator_pipe3 completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline3/pipe_technical_indicator_pipe3.pkl
# After completion of pipe technical_indicator_pipe3, shape of the data is (779894, 129)
# *************************** Pipeline pipeline3 completed.**********************************
# *************************** Pipeline pipeline4 started.**********************************
# [Pipeline(steps=[('rv1',
#                  RollingValues(aggs=['mean', 'mean'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['10min', '30min'])),
#                 ('rv2',
#                  RollingValues(aggs=['max', 'max'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['10min', '30min'])),
#                 ('rv3',
#                  RollingValues(aggs=['max', 'max'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['5min', '30min'])),
#                 ('rv4',
#                  RollingValues(aggs=['max', 'max'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['15min', '60min']))]), Pipeline(steps=[('ltgvc1',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'])),
#                 ('ltgvc2',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=15)),
#                 ('ltgvc3',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=30)),
#                 ('ltgvc4',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=60)),
#                 ('ltgvc5',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=90)),
#                 ('ltgvc6',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=120))])]
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline4.pkl
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline4.csv
# *************************** pipe rolling_values_pipe started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('rv1',
#                  RollingValues(aggs=['mean', 'mean'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['10min', '30min'])),
#                 ('rv2',
#                  RollingValues(aggs=['max', 'max'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['10min', '30min'])),
#                 ('rv3',
#                  RollingValues(aggs=['max', 'max'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['5min', '30min'])),
#                 ('rv4',
#                  RollingValues(aggs=['max', 'max'],
#                                columns=['close', 'open', 'high', 'low'],
#                                last_ticks=['15min', '60min']))])
# Pipe rolling_values_pipe started. Shape of the data is (779894, 4)
# ****************************************************************************************************
# Shape of dataframe after RollingValues is (779894, 8)
# ****************************************************************************************************
# Shape of dataframe after RollingValues is (779894, 12)
# ****************************************************************************************************
# Shape of dataframe after RollingValues is (779894, 16)
# ****************************************************************************************************
# Shape of dataframe after RollingValues is (779894, 20)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline4/pipe_rolling_values_pipe.pkl saved
# pipe rolling_values_pipe completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline4/pipe_rolling_values_pipe.pkl
# After completion of pipe rolling_values_pipe, shape of the data is (779894, 20)
# *************************** pipe last_tick_greater_values_pipe started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('ltgvc1',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'])),
#                 ('ltgvc2',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=15)),
#                 ('ltgvc3',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=30)),
#                 ('ltgvc4',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=60)),
#                 ('ltgvc5',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=90)),
#                 ('ltgvc6',
#                  LastTicksGreaterValuesCount(columns=['close', 'open', 'high',
#                                                       'low'],
#                                              last_ticks=120))])
# Pipe last_tick_greater_values_pipe started. Shape of the data is (779894, 4)
# ****************************************************************************************************
# LastTicksGreaterValuesCount : close : f'last_tick_close_10'
# LastTicksGreaterValuesCount : open : f'last_tick_open_10'
# LastTicksGreaterValuesCount : high : f'last_tick_high_10'
# LastTicksGreaterValuesCount : low : f'last_tick_low_10'
# Shape of dataframe after LastTicksGreaterValuesCount is (779894, 8)
# ****************************************************************************************************
# LastTicksGreaterValuesCount : close : f'last_tick_close_15'
# LastTicksGreaterValuesCount : open : f'last_tick_open_15'
# LastTicksGreaterValuesCount : high : f'last_tick_high_15'
# LastTicksGreaterValuesCount : low : f'last_tick_low_15'
# Shape of dataframe after LastTicksGreaterValuesCount is (779894, 12)
# ****************************************************************************************************
# LastTicksGreaterValuesCount : close : f'last_tick_close_30'
# LastTicksGreaterValuesCount : open : f'last_tick_open_30'
# LastTicksGreaterValuesCount : high : f'last_tick_high_30'
# LastTicksGreaterValuesCount : low : f'last_tick_low_30'
# Shape of dataframe after LastTicksGreaterValuesCount is (779894, 16)
# ****************************************************************************************************
# LastTicksGreaterValuesCount : close : f'last_tick_close_60'
# LastTicksGreaterValuesCount : open : f'last_tick_open_60'
# LastTicksGreaterValuesCount : high : f'last_tick_high_60'
# LastTicksGreaterValuesCount : low : f'last_tick_low_60'
# Shape of dataframe after LastTicksGreaterValuesCount is (779894, 20)
# ****************************************************************************************************
# LastTicksGreaterValuesCount : close : f'last_tick_close_90'
# LastTicksGreaterValuesCount : open : f'last_tick_open_90'
# LastTicksGreaterValuesCount : high : f'last_tick_high_90'
# LastTicksGreaterValuesCount : low : f'last_tick_low_90'
# Shape of dataframe after LastTicksGreaterValuesCount is (779894, 24)
# ****************************************************************************************************
# LastTicksGreaterValuesCount : close : f'last_tick_close_120'
# LastTicksGreaterValuesCount : open : f'last_tick_open_120'
# LastTicksGreaterValuesCount : high : f'last_tick_high_120'
# LastTicksGreaterValuesCount : low : f'last_tick_low_120'
# Shape of dataframe after LastTicksGreaterValuesCount is (779894, 28)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline4/pipe_last_tick_greater_values_pipe.pkl saved
# pipe last_tick_greater_values_pipe completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline4/pipe_last_tick_greater_values_pipe.pkl
# After completion of pipe last_tick_greater_values_pipe, shape of the data is (779894, 28)
# *************************** Pipeline pipeline4 completed.**********************************
# *************************** Pipeline pipeline5 started.**********************************
# [Pipeline(steps=[('zs1',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True, window=10)),
#                 ('zs2',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True, window=15)),
#                 ('zs3',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True)),
#                 ('zs4',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True, window=60)),
#                 ('lgt',
#                  LogTransform(columns=...
#                                   periods=15, verbose=True)),
#                 ('pc3',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   verbose=True)),
#                 ('pc4',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   periods=60, verbose=True)),
#                 ('pc5',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   periods=90, verbose=True)),
#                 ('pc6',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   periods=120, verbose=True))]), Pipeline(steps=[('rr1',
#                  RollingRank(columns=['close', 'open', 'high', 'low'],
#                              window=10)),
#                 ('rr2',
#                  RollingRank(columns=['close', 'open', 'high', 'low'],
#                              window=15)),
#                 ('rr3', RollingRank(columns=['close', 'open', 'high', 'low'])),
#                 ('rr4',
#                  RollingRank(columns=['close', 'open', 'high', 'low'],
#                              window=60)),
#                 ('rr5',
#                  RollingRank(columns=['close', 'open', 'high', 'low'],
#                              window=90)),
#                 ('rr6',
#                  RollingRank(columns=['close', 'open', 'high', 'low'],
#                              window=120))])]
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline5.pkl
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline5.csv
# *************************** pipe zscore_log_percentage_chg_pipe started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('zs1',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True, window=10)),
#                 ('zs2',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True, window=15)),
#                 ('zs3',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True)),
#                 ('zs4',
#                  Zscoring(columns=['close', 'open', 'high', 'low'],
#                           verbose=True, window=60)),
#                 ('lgt',
#                  LogTransform(columns=...
#                                   periods=15, verbose=True)),
#                 ('pc3',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   verbose=True)),
#                 ('pc4',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   periods=60, verbose=True)),
#                 ('pc5',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
#                                   periods=90, verbose=True)),
#                 ('pc6',
#                  PercentageChange(columns=['close', 'open', 'high', 'low'],
# ...
# RRLBC_open_30_None_MINMAX completed
# RRLBC_high_30_None_DIFF completed
# RRLBC_high_30_None_MAXDIFF completed
# RRLBC_high_30_None_MINDIFF completed
# RRLBC_high_30_None_MEANDIFF completed
# RRLBC_high_30_None_MAXMIN completed
# RRLBC_high_30_None_MINMAX completed
# RRLBC_low_30_None_DIFF completed
# RRLBC_low_30_None_MAXDIFF completed
# RRLBC_low_30_None_MINDIFF completed
# RRLBC_low_30_None_MEANDIFF completed
# RRLBC_low_30_None_MAXMIN completed
# RRLBC_low_30_None_MINMAX completed
# Shape of dataframe after Rolling_Stats_withLookBack_Compare is (779894, 340)
# ****************************************************************************************************
# Shape of dataframe before Rolling_Stats_withLookBack_Compare is (779894, 340)
# RRLBC_close_60_None_DIFF completed
# RRLBC_close_60_None_MAXDIFF completed
# RRLBC_close_60_None_MINDIFF completed
# RRLBC_close_60_None_MEANDIFF completed
# RRLBC_close_60_None_MAXMIN completed
# RRLBC_close_60_None_MINMAX completed
# RRLBC_open_60_None_DIFF completed
# RRLBC_open_60_None_MAXDIFF completed
# RRLBC_open_60_None_MINDIFF completed
# RRLBC_open_60_None_MEANDIFF completed
# RRLBC_open_60_None_MAXMIN completed
# RRLBC_open_60_None_MINMAX completed
# RRLBC_high_60_None_DIFF completed
# RRLBC_high_60_None_MAXDIFF completed
# RRLBC_high_60_None_MINDIFF completed
# RRLBC_high_60_None_MEANDIFF completed
# RRLBC_high_60_None_MAXMIN completed
# RRLBC_high_60_None_MINMAX completed
# RRLBC_low_60_None_DIFF completed
# RRLBC_low_60_None_MAXDIFF completed
# RRLBC_low_60_None_MINDIFF completed
# RRLBC_low_60_None_MEANDIFF completed
# RRLBC_low_60_None_MAXMIN completed
# RRLBC_low_60_None_MINMAX completed
# Shape of dataframe after Rolling_Stats_withLookBack_Compare is (779894, 364)
# ****************************************************************************************************
# Shape of dataframe before Rolling_Stats_withLookBack_Compare is (779894, 364)
# RRLBC_close_90_None_DIFF completed
# RRLBC_close_90_None_MAXDIFF completed
# RRLBC_close_90_None_MINDIFF completed
# RRLBC_close_90_None_MEANDIFF completed
# RRLBC_close_90_None_MAXMIN completed
# RRLBC_close_90_None_MINMAX completed
# RRLBC_open_90_None_DIFF completed
# RRLBC_open_90_None_MAXDIFF completed
# RRLBC_open_90_None_MINDIFF completed
# RRLBC_open_90_None_MEANDIFF completed
# RRLBC_open_90_None_MAXMIN completed
# RRLBC_open_90_None_MINMAX completed
# RRLBC_high_90_None_DIFF completed
# RRLBC_high_90_None_MAXDIFF completed
# RRLBC_high_90_None_MINDIFF completed
# RRLBC_high_90_None_MEANDIFF completed
# RRLBC_high_90_None_MAXMIN completed
# RRLBC_high_90_None_MINMAX completed
# RRLBC_low_90_None_DIFF completed
# RRLBC_low_90_None_MAXDIFF completed
# RRLBC_low_90_None_MINDIFF completed
# RRLBC_low_90_None_MEANDIFF completed
# RRLBC_low_90_None_MAXMIN completed
# RRLBC_low_90_None_MINMAX completed
# Shape of dataframe after Rolling_Stats_withLookBack_Compare is (779894, 388)
# ****************************************************************************************************
# Shape of dataframe before Rolling_Stats_withLookBack_Compare is (779894, 388)
# RRLBC_close_120_None_DIFF completed
# RRLBC_close_120_None_MAXDIFF completed
# RRLBC_close_120_None_MINDIFF completed
# RRLBC_close_120_None_MEANDIFF completed
# RRLBC_close_120_None_MAXMIN completed
# RRLBC_close_120_None_MINMAX completed
# RRLBC_open_120_None_DIFF completed
# RRLBC_open_120_None_MAXDIFF completed
# RRLBC_open_120_None_MINDIFF completed
# RRLBC_open_120_None_MEANDIFF completed
# RRLBC_open_120_None_MAXMIN completed
# RRLBC_open_120_None_MINMAX completed
# RRLBC_high_120_None_DIFF completed
# RRLBC_high_120_None_MAXDIFF completed
# RRLBC_high_120_None_MINDIFF completed
# RRLBC_high_120_None_MEANDIFF completed
# RRLBC_high_120_None_MAXMIN completed
# RRLBC_high_120_None_MINMAX completed
# RRLBC_low_120_None_DIFF completed
# RRLBC_low_120_None_MAXDIFF completed
# RRLBC_low_120_None_MINDIFF completed
# RRLBC_low_120_None_MEANDIFF completed
# RRLBC_low_120_None_MAXMIN completed
# RRLBC_low_120_None_MINMAX completed
# Shape of dataframe after Rolling_Stats_withLookBack_Compare is (779894, 412)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline6/pipe_rolling_stats_pipe.pkl saved
# pipe rolling_stats_pipe completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline6/pipe_rolling_stats_pipe.pkl
# After completion of pipe rolling_stats_pipe, shape of the data is (779894, 412)
# *************************** pipe price_range_pipe started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('pltbc1',
#                  PriceLastTickBreachCount(breach_type=['morethan', 'max'],
#                                           columns=['close', 'open', 'high',
#                                                    'low'])),
#                 ('pltbc2',
#                  PriceLastTickBreachCount(breach_type=['morethan', 'max'],
#                                           columns=['close', 'open', 'high',
#                                                    'low'],
#                                           last_ticks='30min')),
#                 ('pltbc3',
#                  PriceLastTickBreachCount(breach_type=['morethan', 'max'],
#                                           columns=['close', 'open', 'high',
#                                                    'low']...
#                                        range_type=['price_range', 'price_deviation_max_first_col', 'price_deviation_min_first_col', 'price_deviation_max_second_col', 'price_deviation_min_second_col'],
#                                        second_col='close')),
#                 ('pdrhw3',
#                  PriceDayRangeHourWise(hour_range=[['09:00', '10:30'], ['10:30', '11:30'], ['11:30', '12:30'], ['12:30', '01:30'], ['02:30', '15:30']],
#                                        range_type=['price_range', 'price_deviation_max_first_col', 'price_deviation_min_first_col', 'price_deviation_max_second_col', 'price_deviation_min_second_col']))])
# Pipe price_range_pipe started. Shape of the data is (779894, 4)
# ****************************************************************************************************
# PriceLastTickBreachCount : morethan : 10min
# PriceLastTickBreachCount : max : 10min
# Shape of dataframe after PriceLastTickBreachCount is (779894, 12)
# ****************************************************************************************************
# PriceLastTickBreachCount : morethan : 30min
# PriceLastTickBreachCount : max : 30min
# Shape of dataframe after PriceLastTickBreachCount is (779894, 20)
# ****************************************************************************************************
# PriceLastTickBreachCount : morethan : 60min
# PriceLastTickBreachCount : max : 60min
# Shape of dataframe after PriceLastTickBreachCount is (779894, 28)
# ****************************************************************************************************
# PriceLastTickBreachCount : morethan : 120min
# PriceLastTickBreachCount : max : 120min
# Shape of dataframe after PriceLastTickBreachCount is (779894, 36)
# ****************************************************************************************************
# Shape of dataframe before PreviousDaysRange is (779894, 36)
# PVDR_close_d_1 completed
# PVDR_open_d_1 completed
# PVDR_high_d_1 completed
# PVDR_low_d_1 completed
# Shape of dataframe after PreviousDaysRange is (779894, 44)
# ****************************************************************************************************
# Shape of dataframe before PreviousDaysRange is (779894, 44)
# PVDR_close_d_1 completed
# PVDR_open_d_1 completed
# PVDR_high_d_1 completed
# PVDR_low_d_1 completed
# Shape of dataframe after PreviousDaysRange is (779894, 52)
# ****************************************************************************************************
# Shape of dataframe before PreviousDaysRange is (779894, 52)
# PVDR_close_d_1 completed
# PVDR_open_d_1 completed
# PVDR_high_d_1 completed
# PVDR_low_d_1 completed
# Shape of dataframe after PreviousDaysRange is (779894, 60)
# ****************************************************************************************************
# Shape of dataframe before PreviousDaysRange is (779894, 60)
# PVDR_close_w_1 completed
# PVDR_open_w_1 completed
# PVDR_high_w_1 completed
# PVDR_low_w_1 completed
# Shape of dataframe after PreviousDaysRange is (779894, 68)
# ****************************************************************************************************
# Shape of dataframe before GapOpenMinuteChart is (779894, 68)
# GOMC_close completed
# GOMC_open completed
# GOMC_high completed
# GOMC_low completed
# Shape of dataframe after GapOpenMinuteChart is (779894, 69)
# ****************************************************************************************************
# PriceDayRangeHourWise : open : close : 09:00 : 10:30 : price_range
# PriceDayRangeHourWise : open : close : 09:00 : 10:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : open : close : 09:00 : 10:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : open : close : 09:00 : 10:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : open : close : 09:00 : 10:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : open : close : 10:30 : 11:30 : price_range
# PriceDayRangeHourWise : open : close : 10:30 : 11:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : open : close : 10:30 : 11:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : open : close : 10:30 : 11:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : open : close : 10:30 : 11:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : open : close : 11:30 : 12:30 : price_range
# PriceDayRangeHourWise : open : close : 11:30 : 12:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : open : close : 11:30 : 12:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : open : close : 11:30 : 12:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : open : close : 11:30 : 12:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : open : close : 12:30 : 01:30 : price_range
# PriceDayRangeHourWise : open : close : 12:30 : 01:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : open : close : 12:30 : 01:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : open : close : 12:30 : 01:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : open : close : 12:30 : 01:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : open : close : 02:30 : 15:30 : price_range
# PriceDayRangeHourWise : open : close : 02:30 : 15:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : open : close : 02:30 : 15:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : open : close : 02:30 : 15:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : open : close : 02:30 : 15:30 : price_deviation_min_second_col
# Shape of dataframe after PriceDayRangeHourWise is (787457, 74)
# ****************************************************************************************************
# PriceDayRangeHourWise : high : low : 09:00 : 10:30 : price_range
# PriceDayRangeHourWise : high : low : 09:00 : 10:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : high : low : 09:00 : 10:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : high : low : 09:00 : 10:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : high : low : 09:00 : 10:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : high : low : 10:30 : 11:30 : price_range
# PriceDayRangeHourWise : high : low : 10:30 : 11:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : high : low : 10:30 : 11:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : high : low : 10:30 : 11:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : high : low : 10:30 : 11:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : high : low : 11:30 : 12:30 : price_range
# PriceDayRangeHourWise : high : low : 11:30 : 12:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : high : low : 11:30 : 12:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : high : low : 11:30 : 12:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : high : low : 11:30 : 12:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : high : low : 12:30 : 01:30 : price_range
# PriceDayRangeHourWise : high : low : 12:30 : 01:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : high : low : 12:30 : 01:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : high : low : 12:30 : 01:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : high : low : 12:30 : 01:30 : price_deviation_min_second_col
# PriceDayRangeHourWise : high : low : 02:30 : 15:30 : price_range
# PriceDayRangeHourWise : high : low : 02:30 : 15:30 : price_deviation_max_first_col
# PriceDayRangeHourWise : high : low : 02:30 : 15:30 : price_deviation_min_first_col
# PriceDayRangeHourWise : high : low : 02:30 : 15:30 : price_deviation_max_second_col
# PriceDayRangeHourWise : high : low : 02:30 : 15:30 : price_deviation_min_second_col
# Shape of dataframe after PriceDayRangeHourWise is (787457, 79)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline6/pipe_price_range_pipe.pkl saved
# pipe price_range_pipe completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline6/pipe_price_range_pipe.pkl
# After completion of pipe price_range_pipe, shape of the data is (787457, 79)
# *************************** Pipeline pipeline6 completed.**********************************
# *************************** Pipeline pipeline7 started.**********************************
# [Pipeline(steps=[('labelgenerator_1', LabelCreator_Light()),
#                 ('labelgenerator_2', LabelCreator_Light(shift=-30)),
#                 ('labelgenerator_3', LabelCreator_Light(shift=-60)),
#                 ('labelgenerator_4', LabelCreator_Light(shift=-45)),
#                 ('labelgenerator_5', LabelCreator_Super_Light()),
#                 ('labelgenerator_6', LabelCreator_Super_Light(shift=-30)),
#                 ('labelgenerator_7', LabelCreator_Super_Light(shift=-60)),
#                 ('labelgenerator_8', LabelCreator_Super_Light(shift=-45))])]
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline7.pkl
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/pipeline7.csv
# *************************** pipe label_creator_pipe started.**********************************
# Below is the descripton of pipe
# Pipeline(steps=[('labelgenerator_1', LabelCreator_Light()),
#                 ('labelgenerator_2', LabelCreator_Light(shift=-30)),
#                 ('labelgenerator_3', LabelCreator_Light(shift=-60)),
#                 ('labelgenerator_4', LabelCreator_Light(shift=-45)),
#                 ('labelgenerator_5', LabelCreator_Super_Light()),
#                 ('labelgenerator_6', LabelCreator_Super_Light(shift=-30)),
#                 ('labelgenerator_7', LabelCreator_Super_Light(shift=-60)),
#                 ('labelgenerator_8', LabelCreator_Super_Light(shift=-45))])
# Pipe label_creator_pipe started. Shape of the data is (779894, 4)
# Shape of dataframe after transform is (779894, 5)
# Shape of dataframe after transform is (779894, 6)
# Shape of dataframe after transform is (779894, 7)
# Shape of dataframe after transform is (779894, 8)
# Shape of dataframe after transform is (779894, 9)
# Shape of dataframe after transform is (779894, 10)
# Shape of dataframe after transform is (779894, 11)
# Shape of dataframe after transform is (779894, 12)
# /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline7/pipe_label_creator_pipe.pkl saved
# pipe label_creator_pipe completed. Save at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_pipeline/pipeline7/pipe_label_creator_pipe.pkl
# After completion of pipe label_creator_pipe, shape of the data is (779894, 12)
# *************************** Pipeline pipeline7 completed.**********************************
# Final pipeline saved to /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/final_pipeline.pkl
# *************************** PIPELINE EXECUTION COMPLETED**********************************

# %%
edp.merge_pipeline(split_flag=True)
# Out:
# Started reading master data from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline1/
# 	Number of files found : 1
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline1/technical_indicator_pipe.csv
# 	Shape of the df is : (23814, 842)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# Completed reading master data from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline1/
# Shape of master df before merge (23814, 838)
# 	Number of files found : 2
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline2/rolling_values_pipe.csv
# 	Shape of the df is : (23814, 20)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline2/last_tick_greater_values_pipe.csv
# 	Shape of the df is : (23814, 28)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# Shape of df in pipeline2 is (23814, 40)
# Shape of data after merging pipeline2 is : (23814, 878)
# 	Number of files found : 2
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline3/zscore_log_percentage_chg_pipe.csv
# 	Shape of the df is : (23814, 52)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline3/rolling_rank_pipe.csv
# 	Shape of the df is : (23814, 28)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# Shape of df in pipeline3 is (23814, 72)
# Shape of data after merging pipeline3 is : (23814, 950)
# 	Number of files found : 4
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline4/bin_transform_pipe.csv
# 	Shape of the df is : (23814, 28)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline4/positive_negative_pipe.csv
# 	Shape of the df is : (23814, 28)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline4/rolling_stats_pipe.csv
# 	Shape of the df is : (23814, 412)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline4/price_range_pipe.csv
# 	Shape of the df is : (24017, 79)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# Shape of df in pipeline4 is (24017, 531)
# Shape of data after merging pipeline4 is : (23814, 1481)
# 	Number of files found : 1
# 	File loaded from path : /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/saved_data_pipeline/pipeline5/label_creator_pipe.csv
# 	Shape of the df is : (23814, 12)
# 	Columns excluded : ['close', 'open', 'high', 'low']
# Shape of df in pipeline5 is (23814, 8)
# Shape of data after merging pipeline5 is : (23814, 1489)
# ****************************************************************************************************
# Value of start_date is 2022-07-01
# Value of end_date is None
# Value of filter_rows is None
# Data filtered with 2022-07-01
# Data filtered with filter rows None
# Train data saved at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/train.csv
# Shape of train df is : (7938, 1489)
# Valid data saved at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/valid.csv
# Shape of valid df is : (5670, 1489)
# Test data saved at location /content/drive/MyDrive/Work/trading/data_files/banknifty/2022-10-06/training/test.csv
# Shape of test df is : (3402, 1489)
