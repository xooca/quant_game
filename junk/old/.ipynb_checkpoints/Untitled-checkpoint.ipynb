# %%
import yfinance as yf

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# %%
import yfinance as yf
data = yf.download("SPY AAPL", start="2017-01-01", end="2019-04-30")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
data.shape
# Out:
# (583, 12)

# %%
data
# Out:
#              Adj Close                   Close                    High  \
#                   AAPL         SPY        AAPL         SPY        AAPL
# Date
# 2017-01-03  110.691154  211.552551  116.150002  225.240005  116.330002
# 2017-01-04  110.567276  212.811111  116.019997  226.580002  116.510002
# 2017-01-05  111.129562  212.642044  116.610001  226.399994  116.860001
# 2017-01-06  112.368469  213.402817  117.910004  227.210007  118.160004
# 2017-01-09  113.397697  212.698441  118.989998  226.460007  119.430000
# ...                ...         ...         ...         ...         ...
# 2019-04-23  204.799362  287.015472  207.479996  292.880005  207.750000
# 2019-04-24  204.483505  286.378540  207.160004  292.230011  208.479996
# 2019-04-25  202.627808  286.202118  205.279999  292.049988  207.759995
# 2019-04-26  201.660461  287.534882  204.300003  293.410004  205.000000
# 2019-04-29  201.966461  287.985657  204.610001  293.869995  205.970001
#
# ...

# %%
data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  3 of 3 completed
#
# 3 Failed downloads:
# - SPY: 1m data not available for startTime=1577868747 and endTime=1588668747. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# - MSFT: 1m data not available for startTime=1577868747 and endTime=1588668747. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# - AAPL: 1m data not available for startTime=1577868747 and endTime=1588668747. Only 7 days worth of 1m granularity data are allowed to be fetched per request.

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
msft.info

# get historical market data
hist = msft.history(period="max")

# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits

# show financials
msft.financials
msft.quarterly_financials

# show major holders
msft.major_holders

# show institutional holders
msft.institutional_holders

# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# get option chain for specific expiration
opt = msft.option_chain('2020-05-08')
# data available via: opt.calls, opt.puts

# %%
opt
# Out:
# Options(calls=         contractSymbol       lastTradeDate  strike  lastPrice  bid  ask  \
# 0   MSFT200508C00140000 2020-05-04 13:59:59   140.0      36.05  0.0  0.0
# 1   MSFT200508C00141000 2020-05-04 15:32:05   141.0      36.53  0.0  0.0
# 2   MSFT200508C00142000 2020-05-04 15:32:05   142.0      35.51  0.0  0.0
# 3   MSFT200508C00143000 2020-04-06 14:28:53   143.0      20.90  0.0  0.0
# 4   MSFT200508C00144000 2020-04-22 16:47:22   144.0      28.74  0.0  0.0
# 5   MSFT200508C00145000 2020-04-29 19:35:13   145.0      32.25  0.0  0.0
# 6   MSFT200508C00146000 2020-04-30 15:54:46   146.0      31.99  0.0  0.0
# 7   MSFT200508C00147000 2020-04-30 13:38:04   147.0      29.76  0.0  0.0
# 8   MSFT200508C00148000 2020-05-04 18:16:12   148.0      29.59  0.0  0.0
# 9   MSFT200508C00149000 2020-05-01 14:01:41   149.0      29.10  0.0  0.0
# 10  MSFT200508C00150000 2020-05-04 15:19:31   150.0      27.60  0.0  0.0
# 11  MSFT200508C00152500 2020-05-01 18:11:26   152.5      22.20  0.0  0.0
# ...

# %%
msft.quarterly_balance_sheet
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
msft.institutional_holders
# Out:
#                               Holder     Shares Date Reported   % Out  \
# 0         Vanguard Group, Inc. (The)  623667281    2019-12-30  0.0820
# 1                     Blackrock Inc.  515197221    2019-12-30  0.0677
# 2           State Street Corporation  315672520    2019-12-30  0.0415
# 3                           FMR, LLC  239124143    2019-12-30  0.0314
# 4            Capital World Investors  180557630    2019-12-30  0.0237
# 5      Price (T.Rowe) Associates Inc  175036277    2019-12-30  0.0230
# 6      Geode Capital Management, LLC  113401519    2019-12-30  0.0149
# 7    Capital International Investors   99996798    2019-12-30  0.0131
# 8         Northern Trust Corporation   93192050    2019-12-30  0.0123
# 9  Capital Research Global Investors   92776236    2019-12-30  0.0122
#
#          Value
# 0  98352330213
# 1  81246601751
# 2  49781556404
# 3  37709877351
# 4  28473938251
# 5  27603220882
# 6  17883419546
# 7  15769495044
# 8  14696386285
# 9  14630812417

# %%
hist
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.07    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2020-04-28  175.59  175.67  169.39  169.81    34392700        0.0
# 2020-04-29  173.22  177.68  171.88  177.43    51286600        0.0
# 2020-04-30  180.00  180.40  176.23  179.21    53875900        0.0
# 2020-05-01  175.80  178.64  174.01  174.57    39370500        0.0
# 2020-05-04  174.49  179.00  173.80  178.84    30336200        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
msft.recommendations
# Out:
#                       Firm       To Grade From Grade Action
# Date
# 2012-03-16  Argus Research            Buy                up
# 2012-03-19  Hilliard Lyons  Long-Term Buy              main
# 2012-03-22  Morgan Stanley     Overweight              main
# 2012-04-03             UBS            Buy              main
# 2012-04-20   Goldman Sachs        Neutral              main
# ...                    ...            ...        ...    ...
# 2020-04-30  Morgan Stanley     Overweight              main
# 2020-04-30       Citigroup        Neutral              main
# 2020-04-30     BMO Capital     Outperform              main
# 2020-04-30   Credit Suisse     Outperform              main
# 2020-04-30          Mizuho            Buy              main
#
# [281 rows x 4 columns]

# %%
import yfinance as yf

infy = yf.Ticker("INFY.NS")

# %%
# get historical market data
infy = infy.history(period="max")

# %%
infy
# Out:
#               Open   High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 1996-01-01   -0.00   -0.0   -0.00   -0.00    204800        0.0           0.0
# 1996-01-02   -0.00   -0.0   -0.00   -0.00    204800        0.0           0.0
# 1996-01-03   -0.00   -0.0   -0.00   -0.00    102400        0.0           0.0
# 1996-01-04   -0.00   -0.0   -0.00   -0.00    307200        0.0           0.0
# 1996-01-05   -0.00   -0.0   -0.00   -0.00     51200        0.0           0.0
# ...            ...    ...     ...     ...       ...        ...           ...
# 2020-04-28  673.00  677.0  653.05  660.70   7296571        0.0           0.0
# 2020-04-29  666.00  682.0  658.00  676.55   8639056        0.0           0.0
# 2020-04-30  700.00  720.0  698.10  715.50  16253821        0.0           0.0
# 2020-05-04  689.80  701.2  670.35  673.70   9122740        0.0           0.0
# 2020-05-05  681.75  685.6  670.00  673.70   6393006        0.0           0.0
#
# [6007 rows x 7 columns]

# %%
import difflib
def matches(lista, listb):
    list1 = lista.copy()
    list2 = listb.copy()
    while True:
        mbs = difflib.SequenceMatcher(None, list1, list2).get_matching_blocks()
        #print(mbs)
        if len(mbs) == 1: break
        for i, j, n in mbs[::-1]:  
            if n > 0: yield list1[i: i + n]
            del list1[i: i + n]
            del list2[j: j + n]
def get_common_sublist(list1,list2):
    t = list(matches(list1, list2))
    common_list = max(t, key=lambda coll: len(coll))
    for i in range(len(list1)):
        if common_sublist == list1[i:len(common_sublist)+i]:
            start = i
            end = i+len(common_sublist)
    return start,end

# %%
a = [2,7,45,34,45,456,565,455,432,45,2,3,45,56,67,76]
b = [7,455,432,45,2,3,45,4]

# %%
a
# Out:
# [2, 7, 45, 34, 45, 456, 565, 455, 432, 45, 2, 3, 45, 56, 67, 76]

# %%
common_sublist = get_common_sublist(a,b)
common_sublist
# Out:
# (7, 13)

# %%
a
# Out:
# [2, 7, 45, 34, 45, 456, 565, 455, 432, 45, 2, 3, 45, 56, 67, 76]

# %%
for i in range(len(a)):
    print(a[i:len(common_sublist)+i])
    if common_sublist == a[i:len(common_sublist)+i]:
        print(i,i+len(common_sublist))
# Out:
# [2, 7, 45, 34, 45, 456]
# [7, 45, 34, 45, 456, 565]
# [45, 34, 45, 456, 565, 455]
# [34, 45, 456, 565, 455, 432]
# [45, 456, 565, 455, 432, 45]
# [456, 565, 455, 432, 45, 2]
# [565, 455, 432, 45, 2, 3]
# [455, 432, 45, 2, 3, 45]
# 7 13
# [432, 45, 2, 3, 45, 56]
# [45, 2, 3, 45, 56, 67]
# [2, 3, 45, 56, 67, 76]
# [3, 45, 56, 67, 76]
# [45, 56, 67, 76]
# [56, 67, 76]
# [67, 76]
# [76]

# %%
b in a
# Out:
# False

# %%
b[1:1] == a
# Out:
# False

# %%
a
# Out:
# [2, 7, 45, 34, 45, 456, 565, 455, 432, 45, 2, 3, 45, 56, 67, 76]

# %%
list3 = set(a)&set(b) # we don't need to list3 to actually be a list

list4 = sorted(list3, key = lambda k : b.index(k))

# %%
list4
# Out:
# [7, 455, 432, 45, 2, 3]

# %%
b
# Out:
# [7, 455, 432, 45, 2, 3, 45, 4]

# %%
for
